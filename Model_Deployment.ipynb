# %%
# !ngrok authtoken 24vK84pvd3NHESBKotaOCW2qpWu_6gzcBsiAY2mUnsd2gLXrK
# Out:
# /bin/bash: ngrok: command not found

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Out:
# --2022-02-10 16:23:25--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.161.241.46, 54.237.133.81, 52.202.168.65, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.161.241.46|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13832437 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.19M  14.0MB/s    in 0.9s
#
# 2022-02-10 16:23:26 (14.0 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13832437/13832437]

# %%
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
get_ipython().system_raw('./ngrok http 8501 &')

# %%
# !curl -s http://localhost:4040/api/tunnels | python3 -c \
  'import sys, json; print("Execute the next line and then go to the ngrok URL: "+json.load(sys.stdin)["tunnels"][0]["public_url"])'
# Out:
# Execute the next line and then go to the ngrok URL: https://674f-34-90-63-146.ngrok.io

# %%
# !streamlit run /content/drive/MyDrive/Colab\ Notebooks/Vegetable_classification/image_prediction.py
# Out:
# 2022-02-10 17:18:29.103 INFO    numexpr.utils: NumExpr defaulting to 2 threads.
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://34.90.63.146:8501
#
#   Stopping...
#   Stopping...

# %%
# !pip install streamlit

# %%
# !pip install pyngrok

# %%
# !nohup streamlit run /content/drive/MyDrive/Colab\ Notebooks/Vegetable_classification/image_prediction.py &
# Out:
# nohup: appending output to 'nohup.out'

# %%
from pyngrok import ngrok

# %%
url = ngrok.connect(port='8501')
url
# Out:
# <NgrokTunnel: "http://cd42-34-90-63-146.ngrok.io" -> "http://localhost:80">
